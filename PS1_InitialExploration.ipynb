# %% [markdown]
# # Initial Exploration of Biblical Texts
#
# Name: Isaac Anderson
#
# Date: Sept 3 2025

# %% [markdown]
# This problem set must accomplish the following tasks:
# 1. Read in 'SF_2009-01-20_GRC_TISCHENDORF_(TISCHENDORF GREEK NT(STRONGS)).xml' and save data to a dataframe (one word per row).
# 2. Parse the rmac codes.
# 3. Read in 'strongs-dictionary.xhtml' and save data to a dataframe (one term per row).
# 4. Compute top 50 lemmas by frequency
#
# **Zipf's law**: in natural language, the frequency of a word is inversely proportion to its rank. e.g. the second more frequent word occurs half as often as the first most frequent word. So the top few words cover a huge fraction of the text.
# If you have $n$ total tokens and sorted counts $f_1, f_2, \ldots, f_3$, the coverage of the first k terms is $C_k = \frac{\sum_{i=1}^k f_i}{n}$
# The ideal Zipf prediction is $p(k) \propto 1/k$. For a finite vocabulary size of $n$, the ideal Zipf prediction is $p(k) = \frac{1/k}{\sum_{i=1}^n 1/i}$
#
# 6. Plot the coverage of the top 20 lemmas and list them in a table along with their Strong's definitions. On this same plot, plot the ideal Zipf prediction for a finite vocabulary size.
# 7. Identify a way to drop out the content-less words and then plot the coverage of these new top 20 lemmas and list them in a table along with their Strong's definitions. On this same plot, plot the ideal Zipf prediction for a finite vocabulary size.
#
# 8. Pickle your dataframes.

# %% [markdown]
# My WORKINGS.

# %%
# Dependancies
import pandas as pd
from bs4 import BeautifulSoup # requires lxml

# %%
tisch_greek = pd.read_xml(
                        "../Data/SF_2009-01-20_GRC_TISCHENDORF_(TISCHENDORF GREEK NT(STRONGS)).xml",
                        parser = "lxml",
                        xpath = "/XMLBIBLE//BIBLEBOOK//CHAPTER//VERS/gr")
tisch_greek.tail()
# Out:
#            str   rmac       gr STYLE
# 137497  3588.0  t-gsm     τοῦ   None
# 137498  2962.0  n-gsm  κυρίου   None
# 137499  2424.0  n-gsm   Ἰησοῦ   None
# 137500  3326.0   prep    μετὰ   None
# 137501  3956.0  a-gpm  πάντων.  None

# %% [markdown]
# ## Problem 2: Parsing RMACS.

# %% [markdown]
# #### Filtering the RMACS.

# %%
# filtering rmacs
tisch_greek['rmac'] = tisch_greek['rmac'].str.lower()
tisch_greek = tisch_greek[~tisch_greek['rmac'].str.endswith('-')]

# %% [markdown]
# #### Scraping RMAC data.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re



index_url = "https://www.modernliteralversion.org/bibles/bs2/RMAC/RMACindex.html"
rmac_url = "https://www.modernliteralversion.org/bibles/bs2/RMAC/"

# Get the metadata for all possible rmacs.
response = requests.get(index_url)
soup = BeautifulSoup(response.text, 'html5lib')

all_links = soup.find('blockquote').find_all('a')

contents = []
hrefs = []
for link in all_links:
    hrefs.append(link.get('href'))
    contents.append(link.text.strip())

# %% [markdown]
# #### RMAC processing function.

# %%
all_labels = [] # used for making rmac database columns.
def decode_rmac(rmac_link: str) -> list:
    print(rmac_url+rmac_link)
    response = requests.get(rmac_url+rmac_link)
    rmac_soup = BeautifulSoup(response.text, 'html5lib')
    rows  = rmac_soup.find_all('tr')
    first_entry = rows[2]

    lines = first_entry.text.split("\n")
    meaningful_lines = []
    for line in lines:
        cleaned_item = line.strip()
        if re.search(r"\w+\: ",cleaned_item):
            cleaned_item = cleaned_item.strip()
            meaningful_lines.append(cleaned_item)
            
    print(meaningful_lines)

    rmac_decoded = []
    for line in meaningful_lines:
        label = re.search(r"(\w+)\:", line).group()
        meaning = re.search(r"(?<=: )\w+", line).group()
        rmac_decoded.append({label: meaning})

        all_labels.append(label) # This is for creating columns down the line. 
    return rmac_decoded

# %%
rmacs_df = pd.DataFrame()
rmacs_df['rmac'] = contents
rmacs_df.head()
# Out:
#       rmac
# 0    A-APF
# 1  A-APF-C
# 2  A-APF-S
# 3    A-APM
# 4  A-APM-C

# %%
rmac_url = "https://www.modernliteralversion.org/bibles/bs2/RMAC/"
new = []
for index, row in rmacs_df.iterrows():
    decoded_rmac_parts = decode_rmac(row['rmac']+".htm")

    for dict_segment in decoded_rmac_parts:
        rmacs_df.at[index, list(dict_segment.keys())[0]] = list(dict_segment.values())[0]
# Out:
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APF.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APF-C.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APF-S.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APM.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APM-C.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APM-S.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APN.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APN-C.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-APN-S.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASF.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASF-C.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASF-N.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASF-S.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine.', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASM.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASM-C.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASM-N.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASM-S.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASN.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASN-C.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASN-N.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-ASN-S.htm
# ['Part of Speech: Adjective.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPF.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPF-C.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPF-S.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPM.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPM-C.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPM-S.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPN.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DPN-S.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSF.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSF-C.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSF-S.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine.', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSM.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSM-C.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSM-N.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSM-S.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine.', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSN.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSN-C.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSN-N.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-DSN-S.htm
# ['Part of Speech: Adjective.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GMS.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Gender: Masculine.', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPF.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPF-S.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPM.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPM-C.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPM-S.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPN.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPN-C.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GPN-S.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSF.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSF-C.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSF-S.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSM.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSM-C.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSM-N.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSM-S.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSN.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSN-N.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from")', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-GSN-S.htm
# ['Part of Speech: Adjective.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing.', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPF.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPF-C.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Feminine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPF-S.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPM.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPM-C.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPM-S.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPN.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPN-C.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NPN-S.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSF.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSF-C.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Feminine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSF-N.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSF-S.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSM.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSM-ATT.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine.', 'Form: ATTic']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSM-C.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSM-N.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSM-S.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSN.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSN-C.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter. As Noun: Â±thing.', 'Degree: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSN-N.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NSN-S.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NUI.htm
# ['Part of Speech: Indeclinable NUmeral (Adjective).', 'Case: Nominative (subject; predicate nominative)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-NUI-ABB.htm
# ['Part of Speech: Adjective.', 'Case: Nominative (subject; predicate nominative).', 'Form: ABBrevieated']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-VPM.htm
# ['Part of Speech: Adjective.', 'Case: Vocative (direct address).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-VSF.htm
# ['Part of Speech: Adjective.', 'Case: Vocative (direct address).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-VSM.htm
# ['Part of Speech: Adjective.', 'Case: Vocative (direct address).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-VSM-S.htm
# ['Part of Speech: Adjective.', 'Case: Vocative (direct address)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/A-VSN.htm
# ['Part of Speech: Adjective.', 'Case: Vocative (direct address)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ADV.htm
# ['Part of Speech: Adverb or adverb and particle combined.', 'Case: Accusative (direct object; motion toward)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ADV-C.htm
# ['Part of Speech: Adverb.', 'Case: Accusative (direct object; motion toward).', 'Form: Comparative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ADV-I.htm
# ['Part of Speech: Adverb.', 'Case: Accusative (direct object; motion toward).', 'Form: Interrogative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ADV-K.htm
# ['Part of Speech: Adverb.', 'Case: Accusative (direct object; motion toward).', 'Form: Contracted with â\x80\x98kaiâ\x80\x99.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ADV-N.htm
# ['Part of Speech: Adverb.', 'Case: Accusative (direct object; motion toward)', 'Degree: Negative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ADV-S.htm
# ['Part of Speech: Adverb.', 'Case: Accusative (direct object; motion toward).', 'Degree: Superlative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/ARAM.htm
# ['Part of Speech: ARAMaic transliterated word (indeclinable)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/C-APM.htm
# ['Part of Speech: reCiprocal pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/C-DPM.htm
# ['Part of Speech: reCiprocal pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/C-DPN.htm
# ['Part of Speech: reCiprocal pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/C-GPM.htm
# ['Part of Speech: reCiprocal pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/C-GPN.htm
# ['Part of Speech: reCiprocal pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/COND.htm
# ['Part of Speech: CONDitional particle or conjunction']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/COND-K.htm
# ['Part of Speech: CONJunction', 'Form: Contracted with â\x80\x98kaiâ\x80\x99. (kai = and or also)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/CONJ.htm
# ['Part of Speech: CONJunction or conjunctive particle']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/CONJ-N.htm
# ['Part of Speech: CONJunction or conjunctive particle Negative']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-APF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-APM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-APM-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine.', 'Form: Contracted with â\x80\x98kaiâ\x80\x99.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-APN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-APN-C.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Form: Contracted.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-APN-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Form: Contracted with â\x80\x98kaiâ\x80\x99.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-ASF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-ASM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-ASM-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine.', 'Form: Contracted with â\x80\x98kaiâ\x80\x99. (kai = and or also)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-ASN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DPF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DPM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DPM-C.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine.', 'Form: Contracted.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DPM-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DPN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DSF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DSM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-DSN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-GPF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-GPM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-GPN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-GSF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-GSM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-GSN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NPF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NPM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NPM-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine.', 'Form: Contracted with â\x80\x98kaiâ\x80\x99.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NPN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NPN-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Form: Contracted with â\x80\x98kaiâ\x80\x99.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NSF.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NSM.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NSM-K.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine.', 'Form: Contracted with â\x80\x98kaiâ\x80\x99.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/D-NSN.htm
# ['Part of Speech: Demonstrative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-1APM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-1ASM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-1DPM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-1DSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-1GPM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-1GSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2APF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2APM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2APN.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2ASM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2ASM-C.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine.', 'Form: Contracted.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2DPF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2DPM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2DSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2GPM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-2GSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3APF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3APM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3APN.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3ASF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3ASM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3ASN.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3DPF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3DPM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3DSF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3DSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3GPF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3GPM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3GPN.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3GSF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3GSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-3GSN.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-GPF.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/F-GSM.htm
# ['Part of Speech: reFlexive pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from")']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/HEB.htm
# ['Part of Speech: HEBrew transliterated word (indeclinable)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-APF.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-APM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-APN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Accusative (direct object; motion toward)']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-ASF.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-ASM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-ASN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-DPM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-DSF.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-DSM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-DSN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-GPM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-GPN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-GSF.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-GSM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-GSN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-NPM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-NPN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-NSF.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-NSM.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/I-NSN.htm
# ['Part of Speech: Interrogative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/INJ.htm
# ['Part of Speech: INterJection']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-APF.htm
# ['Part of Speech: correlative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-APM.htm
# ['Part of Speech: correlative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-APN.htm
# ['Part of Speech: correlative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-ASM.htm
# ['Part of Speech: correlative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-ASN.htm
# ['Part of Speech: correlative pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-DSN.htm
# ['Part of Speech: correlative pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-GPM.htm
# ['Part of Speech: correlative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-GSN.htm
# ['Part of Speech: correlative pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-NPF.htm
# ['Part of Speech: correlative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-NPM.htm
# ['Part of Speech: correlative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-NPN.htm
# ['Part of Speech: correlative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-NSM.htm
# ['Part of Speech: correlative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/K-NSN.htm
# ['Part of Speech: correlative pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APF.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APF-C.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine.', 'Form: Contracted.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APF-S.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APM.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APN.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APN-ATT.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Form: ATTic']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APN-C.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things.', 'Form: Contracted.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-APN-S.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-ASF.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-ASF-C.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine.', 'Form: Contracted.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-ASF-S.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-ASM.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-ASM-S.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward)', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-ASN.htm
# ['Part of Speech: Noun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DPF.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DPM.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DPM-S.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with")', 'Degree: Superlative.']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DPN.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DSF.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DSM.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-DSN.htm
# ['Part of Speech: Noun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-GMP.htm
# ['Part of Speech: Noun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Gender: Masculine. Particle attached']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-GPF.htm
# ['Part of Speech: Noun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-GPM.htm
# ['Part of Speech: Noun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-GPN.htm
# ['Part of Speech: Noun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-GSF.htm
# ['Part of Speech: Noun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/N-GSM.htm
# ...
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RNP-GSF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: middle or passive depoNent G5790.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RNP-NPM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: middle or passive depoNent G5790.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RNP-NSM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: middle or passive depoNent G5790.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPI-1P.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Indicative G5791.', 'Person: First (we).', 'Number: Plural']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPI-1S.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Indicative G5791.', 'Person: First (I).', 'Number: Singular']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPI-2P.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Indicative G5791.', 'Person: Second (you*).', 'Number: Plural']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPI-2S.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Indicative G5791.', 'Person: Second (you).', 'Number: Singular']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPI-3P.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Indicative G5791.', 'Person: Third (they).', 'Number: Plural']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPI-3S.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Indicative G5791.', 'Person: Third (he/she/it).', 'Number: Singular']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPM-2P.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: iMperative G5794.', 'Person: Second (you*).', 'Number: Plural']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPM-2S.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: iMperative G5794.', 'Person: Second (you).', 'Number: Singular']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: iNfinitive G5795']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-APF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-APM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-APN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Plural.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-ASF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-ASF-ATT.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Singular.', 'Gender: Feminine.', 'Form: ATTic']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-ASM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-ASN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-ASN-ATT.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Accusative (direct object; motion toward; time: "how long").', 'Number: Singular.', 'Gender: Neuter.', 'Form: ATTic']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-DPM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "at"; instrument, "with")).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-DPN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "at"; instrument, "with")).', 'Number: Plural.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-DSF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "at"; instrument, "with")).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-DSF-ATT.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "at"; instrument, "with")).', 'Number: Singular.', 'Gender: Feminine.', 'Form: ATTic']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-DSM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "at"; instrument, "with")).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-DSN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "at"; instrument, "with")).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-GPF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-GPM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-GPN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-GSF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-GSM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-GSN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NPF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NPM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NPN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NSF.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NSM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NSN.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-NSN-ATT.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter.', 'Form: ATTic']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-RPP-VSM.htm
# ['Part of Speech: Verb.', 'Tense: peRfect G5778.', 'Voice: Passive G5786.', 'Mood: Participle G5796.', 'Case: Vocative (direct address).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-XXM-2P.htm
# ['Part of Speech: Verb.', 'Tense: no tense stated (adverbial imperative).', 'Voice: no voice stated (denoted by X) G5799.', 'Mood: iMperative G5794.', 'Person: Second (you*).', 'Number: Plural']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/V-XXM-2S.htm
# ['Part of Speech: Verb.', 'Tense: no tense stated (adverbial imperative) (denoted by X) G5799.', 'Voice: no voice stated (denoted by X) G5799.', 'Mood: iMperative G5794.', 'Person: Second (you).', 'Number: Singular']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-APF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-APM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-APN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-ASF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-ASM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-ASN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Accusative (direct object; motion toward).', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-DPM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-DSF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-DSM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-DSN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Dative (indirect object, "to"; also location "in", (rarely): "atâ\x80\x9d; instrument, "with").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-GPF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-GPM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-GPN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-GSF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-GSM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-GSN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Genitive (possession, "of"; also origin or separation, "from").', 'Number: Singular.', 'Gender: Neuter']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-NPF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-NPM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-NPN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Plural.', 'Gender: Neuter. As Noun: Â±things']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-NSF.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Feminine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-NSM.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Masculine']
# https://www.modernliteralversion.org/bibles/bs2/RMAC/X-NSN.htm
# ['Part of Speech: indefinite pronoun.', 'Case: Nominative (subject; predicate nominative).', 'Number: Singular.', 'Gender: Neuter']

# %%
rmacs_df.head()
# Out:
#       rmac    Speech:       Case: Number:    Gender:      Degree: Form:  \
# 0    A-APF  Adjective  Accusative  Plural   Feminine          NaN   NaN
# 1  A-APF-C  Adjective  Accusative  Plural   Feminine  Comparative   NaN
# 2  A-APF-S  Adjective  Accusative     NaN        NaN  Superlative   NaN
# 3    A-APM  Adjective  Accusative  Plural  Masculine          NaN   NaN
# 4  A-APM-C  Adjective  Accusative  Plural  Masculine  Comparative   NaN
#
#   Tense: Voice: Mood: Person:
# 0    NaN    NaN   NaN     NaN
# 1    NaN    NaN   NaN     NaN
# 2    NaN    NaN   NaN     NaN
# 3    NaN    NaN   NaN     NaN
# 4    NaN    NaN   NaN     NaN

# %%
tester = {"hi":"bye"}
print(list(tester.keys())[0])
print(list(tester.values())[0])
# Out:
# hi
# bye

# %%
print(new)
# Out:
# [[{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Plural'}, {'Gender:': 'Feminine'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Plural'}, {'Gender:': 'Feminine'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Plural'}, {'Gender:': 'Masculine'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Plural'}, {'Gender:': 'Masculine'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Plural'}, {'Gender:': 'Neuter'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Plural'}, {'Gender:': 'Neuter'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Feminine'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Feminine'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Negative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Feminine'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Masculine'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Masculine'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Negative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Neuter'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Number:': 'Singular'}, {'Gender:': 'Neuter'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Negative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Accusative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Number:': 'Plural'}, {'Gender:': 'Feminine'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Number:': 'Plural'}, {'Gender:': 'Masculine'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Number:': 'Plural'}, {'Gender:': 'Masculine'}, {'Degree:': 'Comparative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Degree:': 'Superlative'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Number:': 'Plural'}, {'Gender:': 'Neuter'}], [{'Speech:': 'Adjective'}, {'Case:': 'Dative'}, {'Degree:': 'Superlative'}]]

# %% [markdown]
# ## Problem 3: STRONG's Dictionary.

# %%
strongs_dictionary = pd.read_xml("../Data/strongs-dictionary.xhtml")
strongs_dictionary.head()

# using BeautifulSoup4
with open('../Data/strongs-dictionary.xhtml', 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, features='lxml')

words = soup.find_all('li')
print(words[0].text)
strongs_dictionary = pd.DataFrame(words)
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[9], line 6
#       4 # using BeautifulSoup4
#       5 with open('../Data/strongs-dictionary.xhtml', 'r', encoding='utf-8') as file:
# ----> 6     soup = BeautifulSoup(file, features='lxml')
#       8 words = soup.find_all('li')
#       9 print(words[0].text)
#
# File ~/anaconda3/envs/ds2/lib/python3.13/site-packages/bs4/__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
#     373 # At this point either we have a TreeBuilder instance in
#     374 # builder, or we have a builder_class that we can instantiate
#     375 # with the remaining **kwargs.
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
